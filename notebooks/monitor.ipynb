# %% [markdown]
# Start a loop by working on a single object
#
# checkpoint = checkpoints[0]
#
# use a default dict

# %%
# %load_ext autoreload
# %autoreload 2
import json
from collections import defaultdict

from pathlib import Path

from sac.play import *

from sac import checkpoint

expt = 'pendulum'
run = 'test-system'

checkpoints = checkpoint.load(
    f'/Users/adam/git/sac/experiments/{expt}/{run}/'
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# loading buffer from /Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-1/buffer.pkl
# loading buffer from /Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-3/buffer.pkl
# loading buffer from /Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-2/buffer.pkl

# %%
checkpoints
# Out:
# [{'path': PosixPath('/Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-1'),
#   'hyp': {'initial-log-alpha': 0.0,
#    'gamma': 0.99,
#    'rho': 0.995,
#    'buffer-size': 1000,
#    'reward-scale': 5,
#    'lr': 0.0003,
#    'batch-size': 4,
#    'n-episodes': 2,
#    'test-every': 1,
#    'n-tests': 1,
#    'size-scale': 1,
#    'env-name': 'pendulum',
#    'run-name': 'test-system',
#    'buffer': 'new',
#    'target-entropy': -1.0},
#   'env': <sac.env.GymWrapper at 0x13f6fc910>,
#   'nets': {'actor': <tensorflow.python.keras.engine.functional.Functional at 0x13f851c10>,
#    'online-1': <tensorflow.python.keras.engine.functional.Functional at 0x13f94c910>,
#    'online-2': <tensorflow.python.keras.engine.functional.Functional at 0x13f977990>,
#    'target-1': <tensorflow.python.keras.engine.functional.Functional at 0x13f95fc90>,
#    'target-2': <tensorflow.python.keras.engine.functional.Functional at 0x13edc26d0>,
#    'alpha': <tf.Variable 'log-alpha:0' shape=() dtype=float32, numpy=0.0>},
#   'optimizers': {'online-1': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13f9a7750>,
#    'online-2': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13f9a7ad0>,
#    'actor': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13f9a7e50>,
#    'alpha': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13f9a7fd0>},
#   'buffer': <sac.memory.Buffer at 0x13f9a7710>,
#   'rewards': defaultdict(list,
#               {'episode-reward': [-1560.4473876953125],
#                'test-reward': [-1560.4473876953125]}),
#   'counters': defaultdict(int,
#               {'env-steps': 1200,
#                'episodes': 6,
#                'random-episodes': 5,
#                'train-episodes': 0,
#                'test-episodes': 1})},
#  {'path': PosixPath('/Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-3'),
#   'hyp': {'initial-log-alpha': 0.0,
#    'gamma': 0.99,
#    'rho': 0.995,
#    'buffer-size': 1000,
#    'reward-scale': 5,
#    'lr': 0.0003,
#    'batch-size': 4,
#    'n-episodes': 2,
#    'test-every': 1,
#    'n-tests': 1,
#    'size-scale': 1,
#    'env-name': 'pendulum',
#    'run-name': 'test-system',
#    'buffer': 'new',
#    'target-entropy': -1.0},
#   'env': <sac.env.GymWrapper at 0x13f9bc850>,
#   'nets': {'actor': <tensorflow.python.keras.engine.functional.Functional at 0x13f9bc210>,
#    'online-1': <tensorflow.python.keras.engine.functional.Functional at 0x13fa46210>,
#    'online-2': <tensorflow.python.keras.engine.functional.Functional at 0x13f9945d0>,
#    'target-1': <tensorflow.python.keras.engine.functional.Functional at 0x13fa5abd0>,
#    'target-2': <tensorflow.python.keras.engine.functional.Functional at 0x13fa8c850>,
#    'alpha': <tf.Variable 'log-alpha:0' shape=() dtype=float32, numpy=-0.12350609>},
#   'optimizers': {'online-1': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13f9bc390>,
#    'online-2': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13faa11d0>,
#    'actor': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13faa1a90>,
#    'alpha': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13faa16d0>},
#   'buffer': <sac.memory.Buffer at 0x13f9bc090>,
#   'rewards': defaultdict(list,
#               {'episode-reward': [-1560.4473876953125,
#                 -1548.9947509765625,
#                 -1340.825927734375,
#                 -1065.76416015625,
#                 -1015.1513671875],
#                'test-reward': [-1560.4473876953125,
#                 -1340.825927734375,
#                 -1015.1513671875],
#                'train-reward': [-1548.9947509765625, -1065.76416015625]}),
#   'counters': defaultdict(int,
#               {'env-steps': 2000,
#                'episodes': 10,
#                'random-episodes': 5,
#                'train-episodes': 2,
#                'test-episodes': 3,
#                'train-steps': 400,
#                'qfunc-updates': 400,
#                'q-func-update-seconds': 0.02169156499999758,
#                'policy-updates': 400,
#                'pol-func-update-seconds': 0.02231432199999972,
#                'target-update-seconds': 0.0021965270000023907,
#                'alpha-updates': 400,
#                'alpha-update-seconds': 0.013199640999999929})},
#  {'path': PosixPath('/Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-2'),
#   'hyp': {'initial-log-alpha': 0.0,
#    'gamma': 0.99,
#    'rho': 0.995,
#    'buffer-size': 1000,
#    'reward-scale': 5,
#    'lr': 0.0003,
#    'batch-size': 4,
#    'n-episodes': 2,
#    'test-every': 1,
#    'n-tests': 1,
#    'size-scale': 1,
#    'env-name': 'pendulum',
#    'run-name': 'test-system',
#    'buffer': 'new',
#    'target-entropy': -1.0},
#   'env': <sac.env.GymWrapper at 0x13fae1910>,
#   'nets': {'actor': <tensorflow.python.keras.engine.functional.Functional at 0x13faf5190>,
#    'online-1': <tensorflow.python.keras.engine.functional.Functional at 0x13fb69550>,
#    'online-2': <tensorflow.python.keras.engine.functional.Functional at 0x13fb965d0>,
#    'target-1': <tensorflow.python.keras.engine.functional.Functional at 0x13fb517d0>,
#    'target-2': <tensorflow.python.keras.engine.functional.Functional at 0x13fbb2d50>,
#    'alpha': <tf.Variable 'log-alpha:0' shape=() dtype=float32, numpy=-0.06347879>},
#   'optimizers': {'online-1': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13fbc4890>,
#    'online-2': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13fbc4950>,
#    'actor': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13fbc4c10>,
#    'alpha': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13fbc4690>},
#   'buffer': <sac.memory.Buffer at 0x13fbc4290>,
#   'rewards': defaultdict(list,
#               {'episode-reward': [-1560.4473876953125,
#                 -1548.9947509765625,
#                 -1340.825927734375],
#                'test-reward': [-1560.4473876953125, -1340.825927734375],
#                'train-reward': [-1548.9947509765625]}),
#   'counters': defaultdict(int,
#               {'env-steps': 1600,
#                'episodes': 8,
#                'random-episodes': 5,
#                'train-episodes': 1,
#                'test-episodes': 2,
#                'train-steps': 200,
#                'qfunc-updates': 200,
#                'q-func-update-seconds': 0.018592073000000653,
#                'policy-updates': 200,
#                'pol-func-update-seconds': 0.02170024100000134,
#                'target-update-seconds': 0.0017438339999991115,
#                'alpha-updates': 200,
#                'alpha-update-seconds': 0.010552203999999676})}]
