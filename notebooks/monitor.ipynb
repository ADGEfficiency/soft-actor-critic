# %% [markdown]
# Start a loop by working on a single object
#
# checkpoint = checkpoints[0]
#
# use a default dict

# %%
# %load_ext autoreload
# %autoreload 2
import json
from collections import defaultdict

from pathlib import Path

from sac.play import *

from sac import checkpoint

expt = 'pendulum'
run = 'test-system'

checkpoints = checkpoint.load(
    f'/Users/adam/git/sac/experiments/{expt}/{run}/'
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# loading buffer from /Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-1/buffer.pkl
# loading buffer from /Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-3/buffer.pkl
# loading buffer from /Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-2/buffer.pkl

# %%
checkpoints
# Out:
# [{'path': PosixPath('/Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-1'),
#   'hyp': {'initial-log-alpha': 0.0,
#    'gamma': 0.99,
#    'rho': 0.995,
#    'buffer-size': 1000,
#    'reward-scale': 5,
#    'lr': 0.0003,
#    'batch-size': 4,
#    'n-episodes': 2,
#    'test-every': 1,
#    'n-tests': 1,
#    'size-scale': 1,
#    'env-name': 'pendulum',
#    'run-name': 'test-system',
#    'buffer': 'new',
#    'target-entropy': -1.0},
#   'env': <sac.env.GymWrapper at 0x13fc99850>,
#   'nets': {'actor': <tensorflow.python.keras.engine.functional.Functional at 0x13ef44710>,
#    'online-1': <tensorflow.python.keras.engine.functional.Functional at 0x13feeb750>,
#    'online-2': <tensorflow.python.keras.engine.functional.Functional at 0x13ff15910>,
#    'target-1': <tensorflow.python.keras.engine.functional.Functional at 0x13fefeb10>,
#    'target-2': <tensorflow.python.keras.engine.functional.Functional at 0x13ff3c190>,
#    'alpha': <tf.Variable 'log-alpha:0' shape=() dtype=float32, numpy=0.0>},
#   'optimizers': {'online-1': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13ff456d0>,
#    'online-2': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13ff45ed0>,
#    'actor': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13ff45e50>,
#    'alpha': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x13ff45fd0>},
#   'buffer': <sac.memory.Buffer at 0x13ff45b50>,
#   'rewards': defaultdict(list,
#               {'episode-reward': [-1408.4039306640625],
#                'test-reward': [-1408.4039306640625]}),
#   'counters': defaultdict(int,
#               {'env-steps': 1200,
#                'episodes': 6,
#                'random-episodes': 5,
#                'train-episodes': 0,
#                'test-episodes': 1})},
#  {'path': PosixPath('/Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-3'),
#   'hyp': {'initial-log-alpha': 0.0,
#    'gamma': 0.99,
#    'rho': 0.995,
#    'buffer-size': 1000,
#    'reward-scale': 5,
#    'lr': 0.0003,
#    'batch-size': 4,
#    'n-episodes': 2,
#    'test-every': 1,
#    'n-tests': 1,
#    'size-scale': 1,
#    'env-name': 'pendulum',
#    'run-name': 'test-system',
#    'buffer': 'new',
#    'target-entropy': -1.0},
#   'env': <sac.env.GymWrapper at 0x13ff5a890>,
#   'nets': {'actor': <tensorflow.python.keras.engine.functional.Functional at 0x13ff85b10>,
#    'online-1': <tensorflow.python.keras.engine.functional.Functional at 0x13ffe6a90>,
#    'online-2': <tensorflow.python.keras.engine.functional.Functional at 0x13ff96d90>,
#    'target-1': <tensorflow.python.keras.engine.functional.Functional at 0x13fff9bd0>,
#    'target-2': <tensorflow.python.keras.engine.functional.Functional at 0x140028850>,
#    'alpha': <tf.Variable 'log-alpha:0' shape=() dtype=float32, numpy=-0.11549305>},
#   'optimizers': {'online-1': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x1400310d0>,
#    'online-2': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x14003d050>,
#    'actor': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x14003d910>,
#    'alpha': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x14003d850>},
#   'buffer': <sac.memory.Buffer at 0x1400649d0>,
#   'rewards': defaultdict(list,
#               {'episode-reward': [-1408.4039306640625,
#                 -1454.0809326171875,
#                 -1105.6064453125,
#                 -1294.8935546875,
#                 -971.2108764648438],
#                'test-reward': [-1408.4039306640625,
#                 -1105.6064453125,
#                 -971.2108764648438],
#                'train-reward': [-1454.0809326171875, -1294.8935546875]}),
#   'counters': defaultdict(int,
#               {'env-steps': 2000,
#                'episodes': 10,
#                'random-episodes': 5,
#                'train-episodes': 2,
#                'test-episodes': 3,
#                'train-steps': 400,
#                'qfunc-updates': 400,
#                'q-func-update-seconds': 0.01815133199999508,
#                'policy-updates': 400,
#                'pol-func-update-seconds': 0.02053564999999935,
#                'target-update-seconds': 0.0017568789999984347,
#                'alpha-updates': 400,
#                'alpha-update-seconds': 0.010969631000001812})},
#  {'path': PosixPath('/Users/adam/git/sac/experiments/pendulum/test-system/checkpoints/test-episode-2'),
#   'hyp': {'initial-log-alpha': 0.0,
#    'gamma': 0.99,
#    'rho': 0.995,
#    'buffer-size': 1000,
#    'reward-scale': 5,
#    'lr': 0.0003,
#    'batch-size': 4,
#    'n-episodes': 2,
#    'test-every': 1,
#    'n-tests': 1,
#    'size-scale': 1,
#    'env-name': 'pendulum',
#    'run-name': 'test-system',
#    'buffer': 'new',
#    'target-entropy': -1.0},
#   'env': <sac.env.GymWrapper at 0x140077850>,
#   'nets': {'actor': <tensorflow.python.keras.engine.functional.Functional at 0x1400aab50>,
#    'online-1': <tensorflow.python.keras.engine.functional.Functional at 0x1401081d0>,
#    'online-2': <tensorflow.python.keras.engine.functional.Functional at 0x140135a10>,
#    'target-1': <tensorflow.python.keras.engine.functional.Functional at 0x140128510>,
#    'target-2': <tensorflow.python.keras.engine.functional.Functional at 0x140151cd0>,
#    'alpha': <tf.Variable 'log-alpha:0' shape=() dtype=float32, numpy=-0.056057576>},
#   'optimizers': {'online-1': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x140163810>,
#    'online-2': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x140163b90>,
#    'actor': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x1401632d0>,
#    'alpha': <tensorflow.python.keras.optimizer_v2.adam.Adam at 0x140163ad0>},
#   'buffer': <sac.memory.Buffer at 0x14016e4d0>,
#   'rewards': defaultdict(list,
#               {'episode-reward': [-1408.4039306640625,
#                 -1454.0809326171875,
#                 -1105.6064453125],
#                'test-reward': [-1408.4039306640625, -1105.6064453125],
#                'train-reward': [-1454.0809326171875]}),
#   'counters': defaultdict(int,
#               {'env-steps': 1600,
#                'episodes': 8,
#                'random-episodes': 5,
#                'train-episodes': 1,
#                'test-episodes': 2,
#                'train-steps': 200,
#                'qfunc-updates': 200,
#                'q-func-update-seconds': 0.01971010200000123,
#                'policy-updates': 200,
#                'pol-func-update-seconds': 0.020813479000000967,
#                'target-update-seconds': 0.002219945999996753,
#                'alpha-updates': 200,
#                'alpha-update-seconds': 0.010392417999998571})}]
